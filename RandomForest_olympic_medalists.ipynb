# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# reading csv file
athlete_events = pd.read_csv('athlete_events.csv')

# %%
athlete_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
filter_data = athlete_events[["Sex", "Age", "Height", "Weight", "Team", "Year", "Season", "Sport", "Event", "Medal"]]

# %%
# get the data for summer and winter Olympic
winter_data = filter_data[filter_data["Season"] == "Winter"]
summer_data = filter_data[(filter_data["Season"] == "Summer")]

# %%
summer_sports = summer_data["Sport"].unique()

# %%
# For loop to train the Random Forest model and get the testing score for male athletes in every Summer Olympic Sport
for sport in summer_sports:
    try:
        athlete_m  = summer_data[(summer_data["Sport"] == f'{sport}') & (summer_data["Sex"] == "M")]
        athlete_m  = athlete_m [["Age", "Height", "Weight", "Medal"]]
        athlete_m  = athlete_m .dropna(subset=['Height', 'Weight']).reset_index(drop = True)
        
        # One-hot encoding                

        athlete_m  = athlete_m .replace("Gold", 1)
        athlete_m  = athlete_m .replace("Silver", 1)
        athlete_m  = athlete_m .replace("Bronze", 1)
        athlete_m ["Medal"] = athlete_m ["Medal"].fillna(0)
        athlete_m  = athlete_m .dropna()
        athlete_m ["Medal"].unique()

        print(sport)
        
        # Assign X (data) and y (target)        

        target = athlete_m ["Medal"]
        target_names = ["Medals", "None"]
        data = athlete_m .drop("Medal", axis=1)
        feature_names = data.columns
        data.head()
        
        # Split our data into training and testing

        X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)
        clf = tree.DecisionTreeClassifier()
        clf = clf.fit(X_train, y_train)
        clf.score(X_test, y_test)
        
        # Create a random forest classifier

        rf = RandomForestClassifier(n_estimators=200)
        rf = rf.fit(X_train, y_train)
        print("Training Data Score:", rf.score(X_train, y_train)) 
        print("Testing Data Score:", rf.score(X_test, y_test))
        
        # Sort the features by their importance

        print(sorted(zip(rf.feature_importances_, feature_names), reverse=True))
        print("----------------------------------------------------")
    except:
        print("An exception occurred")
        print("----------------------------------------------------")
# Out:
# Basketball
# Training Data Score: 0.9723577235772358
# Testing Data Score: 0.6866883116883117
# [(0.4135832470323039, 'Weight'), (0.3589876609074577, 'Height'), (0.22742909206023829, 'Age')]
# ----------------------------------------------------
# Judo
# Training Data Score: 0.9588963963963963
# Testing Data Score: 0.8279932546374368
# [(0.3883611733772321, 'Weight'), (0.3737552388816325, 'Height'), (0.2378835877411354, 'Age')]
# ----------------------------------------------------
# Football
# Training Data Score: 0.9175019275250579
# Testing Data Score: 0.6982658959537572
# [(0.39295451613935334, 'Weight'), (0.37743609210058093, 'Height'), (0.22960939176006578, 'Age')]
# ----------------------------------------------------
# Tug-Of-War
# Training Data Score: 1.0
# Testing Data Score: 0.4
# [(0.4297730937933319, 'Weight'), (0.3216689928743095, 'Height'), (0.24855791333235858, 'Age')]
# ----------------------------------------------------
# Athletics
# Training Data Score: 0.9291903010658854
# Testing Data Score: 0.8577038145100973
# [(0.4381302767086957, 'Weight'), (0.32193050655741284, 'Height'), (0.2399392167338915, 'Age')]
# ----------------------------------------------------
# Swimming
# Training Data Score: 0.9191214470284238
# Testing Data Score: 0.8651685393258427
# [(0.3951821589545711, 'Weight'), (0.36315699095528586, 'Height'), (0.24166085009014315, 'Age')]
# ----------------------------------------------------
# Badminton
# Training Data Score: 0.9771863117870723
# Testing Data Score: 0.8636363636363636
# [(0.3822921856099616, 'Height'), (0.3399231656144729, 'Weight'), (0.27778464877556563, 'Age')]
# ----------------------------------------------------
# Sailing
# Training Data Score: 0.9762859051436206
# Testing Data Score: 0.8306613226452906
# [(0.37798097781183815, 'Weight'), (0.33783097880750895, 'Age'), (0.28418804338065284, 'Height')]
# ----------------------------------------------------
# Gymnastics
# Training Data Score: 0.9458987783595113
# Testing Data Score: 0.9338070306656694
# [(0.3661668170444642, 'Age'), (0.333143733398819, 'Height'), (0.3006894495567168, 'Weight')]
# ----------------------------------------------------
# Art Competitions
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.3753682457472159, 'Height'), (0.3164518686351481, 'Weight'), (0.30817988561763604, 'Age')]
# ----------------------------------------------------
# Handball
# Training Data Score: 0.9633267845448592
# Testing Data Score: 0.6777996070726916
# [(0.3871497690019516, 'Weight'), (0.3288582395532212, 'Height'), (0.2839919914448273, 'Age')]
# ----------------------------------------------------
# Weightlifting
# Training Data Score: 0.9692307692307692
# Testing Data Score: 0.7965023847376789
# [(0.4385892699687564, 'Weight'), (0.35895352544699227, 'Height'), (0.20245720458425132, 'Age')]
# ----------------------------------------------------
# Wrestling
# Training Data Score: 0.9404696886947024
# Testing Data Score: 0.769041769041769
# [(0.4102707661757348, 'Weight'), (0.34770253298261444, 'Height'), (0.24202670084165065, 'Age')]
# ----------------------------------------------------
# Water Polo
# Training Data Score: 0.9641362821279139
# Testing Data Score: 0.6845878136200717
# [(0.3812909173810874, 'Weight'), (0.32508451515297926, 'Height'), (0.29362456746593335, 'Age')]
# ----------------------------------------------------
# Hockey
# Training Data Score: 0.9419953596287703
# Testing Data Score: 0.6717663421418637
# [(0.3768930543476407, 'Weight'), (0.34547927780968557, 'Height'), (0.27762766784267384, 'Age')]
# ----------------------------------------------------
# Rowing
# Training Data Score: 0.9138823529411765
# Testing Data Score: 0.6923076923076923
# [(0.3783802840847272, 'Weight'), (0.3477016467270419, 'Height'), (0.273918069188231, 'Age')]
# ----------------------------------------------------
# Fencing
# Training Data Score: 0.9146136618141097
# Testing Data Score: 0.801007556675063
# [(0.35575561774140513, 'Weight'), (0.3269761041047067, 'Age'), (0.3172682781538882, 'Height')]
# ----------------------------------------------------
# Equestrianism
# Training Data Score: 0.9168627450980392
# Testing Data Score: 0.8376470588235294
# [(0.370971117844712, 'Age'), (0.3164548671254505, 'Height'), (0.3125740150298375, 'Weight')]
# ----------------------------------------------------
# Shooting
# Training Data Score: 0.9745055992375506
# Testing Data Score: 0.90421729807005
# [(0.39077048722799407, 'Weight'), (0.3105899045443092, 'Height'), (0.2986396082276967, 'Age')]
# ----------------------------------------------------
# Boxing
# Training Data Score: 0.9275092936802974
# Testing Data Score: 0.8113382899628253
# [(0.4126303884250418, 'Height'), (0.36020565321930303, 'Weight'), (0.2271639583556552, 'Age')]
# ----------------------------------------------------
# Taekwondo
# Training Data Score: 0.9956331877729258
# Testing Data Score: 0.7532467532467533
# [(0.39556324863251835, 'Height'), (0.3049340043924679, 'Age'), (0.2995027469750138, 'Weight')]
# ----------------------------------------------------
# Cycling
# Training Data Score: 0.9457219805262067
# Testing Data Score: 0.8633540372670807
# [(0.3803018054185767, 'Weight'), (0.335335622120215, 'Height'), (0.2843625724612083, 'Age')]
# ----------------------------------------------------
# Diving
# Training Data Score: 0.948849104859335
# Testing Data Score: 0.8275862068965517
# [(0.34221149960046177, 'Weight'), (0.3339219630210373, 'Height'), (0.32386653737850096, 'Age')]
# ----------------------------------------------------
# Canoeing
# Training Data Score: 0.9344159900062461
# Testing Data Score: 0.7855805243445693
# [(0.3676868060133611, 'Weight'), (0.3429467426076269, 'Height'), (0.28936645137901207, 'Age')]
# ----------------------------------------------------
# Tennis
# Training Data Score: 0.9591315453384419
# Testing Data Score: 0.8735632183908046
# [(0.34867738214671457, 'Weight'), (0.3354287681390516, 'Age'), (0.31589384971423373, 'Height')]
# ----------------------------------------------------
# Modern Pentathlon
# Training Data Score: 0.9269183922046285
# Testing Data Score: 0.8795620437956204
# [(0.36892659711154463, 'Weight'), (0.32161299184855174, 'Height'), (0.3094604110399037, 'Age')]
# ----------------------------------------------------
# Golf
# Training Data Score: 1.0
# Testing Data Score: 0.9285714285714286
# [(0.47880468814222, 'Height'), (0.31936195394452493, 'Weight'), (0.20183335791325513, 'Age')]
# ----------------------------------------------------
# Softball
# An exception occurred
# ----------------------------------------------------
# Archery
# Training Data Score: 0.94
# Testing Data Score: 0.856
# [(0.3830138844728172, 'Weight'), (0.346546738297494, 'Age'), (0.27043937722968886, 'Height')]
# ----------------------------------------------------
# Volleyball
# Training Data Score: 0.9595808383233533
# Testing Data Score: 0.6143497757847534
# [(0.3753508010321082, 'Weight'), (0.36486836555084173, 'Height'), (0.25978083341705016, 'Age')]
# ----------------------------------------------------
# Synchronized Swimming
# An exception occurred
# ----------------------------------------------------
# Table Tennis
# Training Data Score: 0.9553956834532374
# Testing Data Score: 0.8879310344827587
# [(0.35434746500970676, 'Age'), (0.34544441036115814, 'Weight'), (0.30020812462913515, 'Height')]
# ----------------------------------------------------
# Baseball
# Training Data Score: 0.9716088328075709
# Testing Data Score: 0.5566037735849056
# [(0.3875481512035036, 'Weight'), (0.334044948265854, 'Height'), (0.27840690053064243, 'Age')]
# ----------------------------------------------------
# Rhythmic Gymnastics
# An exception occurred
# ----------------------------------------------------
# Rugby Sevens
# Training Data Score: 1.0
# Testing Data Score: 0.6842105263157895
# [(0.3860325964386903, 'Height'), (0.35169488324334003, 'Weight'), (0.2622725203179697, 'Age')]
# ----------------------------------------------------
# Trampolining
# Training Data Score: 1.0
# Testing Data Score: 0.7894736842105263
# [(0.42624909719110743, 'Weight'), (0.31867910304010316, 'Age'), (0.2550717997687895, 'Height')]
# ----------------------------------------------------
# Beach Volleyball
# Training Data Score: 0.9950980392156863
# Testing Data Score: 0.9130434782608695
# [(0.3410824052526928, 'Height'), (0.33174292580510145, 'Weight'), (0.32717466894220587, 'Age')]
# ----------------------------------------------------
# Triathlon
# Training Data Score: 1.0
# Testing Data Score: 0.9104477611940298
# [(0.38904542662335573, 'Height'), (0.32492712572608623, 'Age'), (0.28602744765055804, 'Weight')]
# ----------------------------------------------------
# Rugby
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Lacrosse
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Polo
# An exception occurred
# ----------------------------------------------------
# Cricket
# An exception occurred
# ----------------------------------------------------
# Ice Hockey
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Racquets
# An exception occurred
# ----------------------------------------------------
# Motorboating
# An exception occurred
# ----------------------------------------------------
# Croquet
# An exception occurred
# ----------------------------------------------------
# Figure Skating
# An exception occurred
# ----------------------------------------------------
# Jeu De Paume
# An exception occurred
# ----------------------------------------------------
# Roque
# An exception occurred
# ----------------------------------------------------
# Basque Pelota
# An exception occurred
# ----------------------------------------------------
# Alpinism
# An exception occurred
# ----------------------------------------------------
# Aeronautics
# An exception occurred
# ----------------------------------------------------

# %%
# For loop to train the Random Forest model and get the testing score for female athletes in every Summer Olympic Sport
for sport in summer_sports:
    try:
        athlete_f  = summer_data[(summer_data["Sport"] == f'{sport}') & (summer_data["Sex"] == "M")]
        athlete_f  = athlete_f [["Age", "Height", "Weight", "Medal"]]
        athlete_f  = athlete_f .dropna(subset=['Height', 'Weight']).reset_index(drop = True)
        
        # One-hot encoding                

        athlete_f  = athlete_f .replace("Gold", 1)
        athlete_f  = athlete_f .replace("Silver", 1)
        athlete_f  = athlete_f .replace("Bronze", 1)
        athlete_f ["Medal"] = athlete_f ["Medal"].fillna(0)
        athlete_f  = athlete_f .dropna()
        athlete_f ["Medal"].unique()

        print(sport)
        
        # Assign X (data) and y (target)        

        target = athlete_f ["Medal"]
        target_names = ["Medals", "None"]
        data = athlete_f .drop("Medal", axis=1)
        feature_names = data.columns
        data.head()
        
        # Split our data into training and testing

        X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)
        clf = tree.DecisionTreeClassifier()
        clf = clf.fit(X_train, y_train)
        clf.score(X_test, y_test)
        
        # Create a random forest classifier

        rf = RandomForestClassifier(n_estimators=200)
        rf = rf.fit(X_train, y_train)
        print("Training Data Score:", rf.score(X_train, y_train)) 
        print("Testing Data Score:", rf.score(X_test, y_test))

        #-------------------------

        # Create our predictions
        prediction = clf.predict(X_test)
        # Create confusion matrix
        from sklearn.metrics import confusion_matrix, f1_score, accuracy_score
        confusion_matrix(y_test, prediction)
        # Display accuracy score
        accuracy_score(y_test, prediction)
        # Display F1 score
        f1_score(y_test,prediction)

        #-------------------------
        
        # Sort the features by their importance
        
        print(sorted(zip(rf.feature_importances_, feature_names), reverse=True))
        print("----------------------------------------------------")
    except:
        print("An exception occurred")
        print("----------------------------------------------------")
# Out:
# Basketball
# Training Data Score: 0.9723577235772358
# Testing Data Score: 0.6834415584415584
# [(0.4169280073790112, 'Weight'), (0.35101712069278956, 'Height'), (0.23205487192819932, 'Age')]
# ----------------------------------------------------
# Judo
# Training Data Score: 0.9588963963963963
# Testing Data Score: 0.8195615514333895
# [(0.38478977697675537, 'Weight'), (0.36823356819880915, 'Height'), (0.24697665482443545, 'Age')]
# ----------------------------------------------------
# Football
# Training Data Score: 0.9175019275250579
# Testing Data Score: 0.7063583815028902
# [(0.3926123393037235, 'Height'), (0.3817687861673515, 'Weight'), (0.225618874528925, 'Age')]
# ----------------------------------------------------
# Tug-Of-War
# Training Data Score: 1.0
# Testing Data Score: 0.4
# [(0.4811100039730994, 'Weight'), (0.2692989036591714, 'Age'), (0.2495910923677292, 'Height')]
# ----------------------------------------------------
# Athletics
# Training Data Score: 0.9291903010658854
# Testing Data Score: 0.8599476439790575
# [(0.4350256073255377, 'Weight'), (0.32439773310963205, 'Height'), (0.24057665956483026, 'Age')]
# ----------------------------------------------------
# Swimming
# Training Data Score: 0.9191214470284238
# Testing Data Score: 0.8632313056954669
# [(0.406743706935582, 'Weight'), (0.35494783741958685, 'Height'), (0.23830845564483116, 'Age')]
# ----------------------------------------------------
# Badminton
# Training Data Score: 0.9771863117870723
# Testing Data Score: 0.8522727272727273
# [(0.3791973478801995, 'Height'), (0.3360868080234277, 'Weight'), (0.2847158440963729, 'Age')]
# ----------------------------------------------------
# Sailing
# Training Data Score: 0.9762859051436206
# Testing Data Score: 0.8306613226452906
# [(0.3717372035534091, 'Weight'), (0.3478603607490216, 'Age'), (0.2804024356975693, 'Height')]
# ----------------------------------------------------
# Gymnastics
# Training Data Score: 0.9458987783595113
# Testing Data Score: 0.9345549738219895
# [(0.3545424826068961, 'Age'), (0.3318352048753761, 'Height'), (0.3136223125177278, 'Weight')]
# ----------------------------------------------------
# Art Competitions
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.3840855173720037, 'Height'), (0.32573691451049636, 'Weight'), (0.2901775681175, 'Age')]
# ----------------------------------------------------
# Handball
# Training Data Score: 0.9633267845448592
# Testing Data Score: 0.6797642436149313
# [(0.3787077637671948, 'Weight'), (0.3290801398168676, 'Height'), (0.2922120964159376, 'Age')]
# ----------------------------------------------------
# Weightlifting
# Training Data Score: 0.9692307692307692
# Testing Data Score: 0.8044515103338633
# [(0.4397348126430493, 'Weight'), (0.3540941934988108, 'Height'), (0.20617099385813983, 'Age')]
# ----------------------------------------------------
# Wrestling
# Training Data Score: 0.9404696886947024
# Testing Data Score: 0.7674037674037674
# [(0.4065076071058942, 'Weight'), (0.33794800417348614, 'Height'), (0.25554438872061974, 'Age')]
# ----------------------------------------------------
# Water Polo
# Training Data Score: 0.9641362821279139
# Testing Data Score: 0.6863799283154122
# [(0.3767264490997593, 'Weight'), (0.3340240641260809, 'Height'), (0.28924948677415985, 'Age')]
# ----------------------------------------------------
# Hockey
# Training Data Score: 0.9419953596287703
# Testing Data Score: 0.6662030598052852
# [(0.37680919011145114, 'Weight'), (0.35034171329110697, 'Height'), (0.272849096597442, 'Age')]
# ----------------------------------------------------
# Rowing
# Training Data Score: 0.9138823529411765
# Testing Data Score: 0.6986591390261115
# [(0.3832828505416879, 'Weight'), (0.3486832181594801, 'Height'), (0.26803393129883196, 'Age')]
# ----------------------------------------------------
# Fencing
# Training Data Score: 0.9146136618141097
# Testing Data Score: 0.799328295549958
# [(0.37465189504038904, 'Weight'), (0.31560256625726385, 'Height'), (0.3097455387023471, 'Age')]
# ----------------------------------------------------
# Equestrianism
# Training Data Score: 0.9168627450980392
# Testing Data Score: 0.8364705882352941
# [(0.3671841494825539, 'Age'), (0.31650734973245553, 'Height'), (0.31630850078499056, 'Weight')]
# ----------------------------------------------------
# Shooting
# Training Data Score: 0.9745055992375506
# Testing Data Score: 0.9049320943531094
# [(0.381048401583346, 'Weight'), (0.312462494522383, 'Height'), (0.3064891038942709, 'Age')]
# ----------------------------------------------------
# Boxing
# Training Data Score: 0.9275092936802974
# Testing Data Score: 0.8122676579925651
# [(0.4087311295934051, 'Height'), (0.35795623597470916, 'Weight'), (0.2333126344318859, 'Age')]
# ----------------------------------------------------
# Taekwondo
# Training Data Score: 0.9956331877729258
# Testing Data Score: 0.7402597402597403
# [(0.39544916099266014, 'Height'), (0.3103003665962961, 'Age'), (0.29425047241104374, 'Weight')]
# ----------------------------------------------------
# Cycling
# Training Data Score: 0.9457219805262067
# Testing Data Score: 0.8608695652173913
# [(0.39475420403607997, 'Weight'), (0.3245668671418553, 'Height'), (0.28067892882206474, 'Age')]
# ----------------------------------------------------
# Diving
# Training Data Score: 0.948849104859335
# Testing Data Score: 0.8352490421455939
# [(0.3469950863252679, 'Weight'), (0.3284522435450693, 'Height'), (0.32455267012966293, 'Age')]
# ----------------------------------------------------
# Canoeing
# Training Data Score: 0.9344159900062461
# Testing Data Score: 0.7808988764044944
# [(0.3585957584690158, 'Weight'), (0.35628292164240294, 'Height'), (0.28512131988858125, 'Age')]
# ----------------------------------------------------
# Tennis
# Training Data Score: 0.9591315453384419
# Testing Data Score: 0.8735632183908046
# [(0.34624467207590465, 'Weight'), (0.32810086633730845, 'Height'), (0.32565446158678685, 'Age')]
# ----------------------------------------------------
# Modern Pentathlon
# Training Data Score: 0.9269183922046285
# Testing Data Score: 0.8722627737226277
# [(0.3637961255288459, 'Weight'), (0.33023276062694, 'Height'), (0.30597111384421405, 'Age')]
# ----------------------------------------------------
# Golf
# Training Data Score: 1.0
# Testing Data Score: 0.9285714285714286
# [(0.5437414857150793, 'Height'), (0.2829622228750898, 'Weight'), (0.1732962914098309, 'Age')]
# ----------------------------------------------------
# Softball
# An exception occurred
# ----------------------------------------------------
# Archery
# Training Data Score: 0.94
# Testing Data Score: 0.856
# [(0.40164177140412904, 'Weight'), (0.3220610561978237, 'Age'), (0.2762971723980474, 'Height')]
# ----------------------------------------------------
# Volleyball
# Training Data Score: 0.9595808383233533
# Testing Data Score: 0.6322869955156951
# [(0.36862026505715534, 'Weight'), (0.361387086779894, 'Height'), (0.2699926481629507, 'Age')]
# ----------------------------------------------------
# Synchronized Swimming
# An exception occurred
# ----------------------------------------------------
# Table Tennis
# Training Data Score: 0.9553956834532374
# Testing Data Score: 0.8836206896551724
# [(0.3511101198675533, 'Weight'), (0.33954860834332246, 'Age'), (0.3093412717891243, 'Height')]
# ----------------------------------------------------
# Baseball
# Training Data Score: 0.9716088328075709
# Testing Data Score: 0.5660377358490566
# [(0.3924757229002203, 'Weight'), (0.32625004628515375, 'Height'), (0.281274230814626, 'Age')]
# ----------------------------------------------------
# Rhythmic Gymnastics
# An exception occurred
# ----------------------------------------------------
# Rugby Sevens
# Training Data Score: 1.0
# Testing Data Score: 0.6842105263157895
# [(0.392785805394429, 'Height'), (0.34988484712835094, 'Weight'), (0.2573293474772201, 'Age')]
# ----------------------------------------------------
# Trampolining
# Training Data Score: 1.0
# Testing Data Score: 0.7894736842105263
# [(0.4089292287689651, 'Weight'), (0.32816739108232323, 'Age'), (0.2629033801487116, 'Height')]
# ----------------------------------------------------
# Beach Volleyball
# Training Data Score: 0.9950980392156863
# Testing Data Score: 0.9130434782608695
# [(0.3467226138096092, 'Height'), (0.3284219556784633, 'Age'), (0.3248554305119273, 'Weight')]
# ----------------------------------------------------
# Triathlon
# Training Data Score: 1.0
# Testing Data Score: 0.9104477611940298
# [(0.39307772224395243, 'Height'), (0.3169817789629718, 'Age'), (0.2899404987930759, 'Weight')]
# ----------------------------------------------------
# Rugby
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Lacrosse
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Polo
# An exception occurred
# ----------------------------------------------------
# Cricket
# An exception occurred
# ----------------------------------------------------
# Ice Hockey
# Training Data Score: 1.0
# Testing Data Score: 1.0
# [(0.0, 'Weight'), (0.0, 'Height'), (0.0, 'Age')]
# ----------------------------------------------------
# Racquets
# An exception occurred
# ----------------------------------------------------
# Motorboating
# An exception occurred
# ----------------------------------------------------
# Croquet
# An exception occurred
# ----------------------------------------------------
# Figure Skating
# An exception occurred
# ----------------------------------------------------
# Jeu De Paume
# An exception occurred
# ----------------------------------------------------
# Roque
# An exception occurred
# ----------------------------------------------------
# Basque Pelota
# An exception occurred
# ----------------------------------------------------
# Alpinism
# An exception occurred
# ----------------------------------------------------
# Aeronautics
# An exception occurred
# ----------------------------------------------------
